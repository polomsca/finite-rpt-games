# %% [markdown]
# # Model

# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd
import string as string

# %% [markdown]
# ## Dataset

# %%
actions = pd.read_csv('actions.csv')
players = actions['player'].unique()
for i in range(len(players)):
    players_index = actions['player'][actions['player'] == players[i]].index

# %%
import_csv
# Out:
#        session dropout  day  game  round             gameId  \
# 0          1pm   False    1     1      1  Afom9bWqYBgZXXXN8
# 1          1pm   False    1     1      1  Afom9bWqYBgZXXXN8
# 2          1pm   False    1     1      2  Afom9bWqYBgZXXXN8
# 3          1pm   False    1     1      2  Afom9bWqYBgZXXXN8
# 4          1pm   False    1     1      3  Afom9bWqYBgZXXXN8
# 5          1pm   False    1     1      3  Afom9bWqYBgZXXXN8
# 6          1pm   False    1     1      4  Afom9bWqYBgZXXXN8
# 7          1pm   False    1     1      4  Afom9bWqYBgZXXXN8
# 8          1pm   False    1     1      5  Afom9bWqYBgZXXXN8
# 9          1pm   False    1     1      5  Afom9bWqYBgZXXXN8
# 10         1pm   False    1     1      6  Afom9bWqYBgZXXXN8
# 11         1pm   False    1     1      6  Afom9bWqYBgZXXXN8
# 12         1pm   False    1     1      7  Afom9bWqYBgZXXXN8
# 13         1pm   False    1     1      7  Afom9bWqYBgZXXXN8
# 14         1pm   False    1     1      8  Afom9bWqYBgZXXXN8
# ...
